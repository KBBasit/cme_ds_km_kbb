# %%
import requests
import numpy as np

# %%
base_url = "https://api.gdeltproject.org/api/v2/doc/doc?"


queries = [
    "energy",
    "oil",
    "crude oil",
    "natural gas",
    "LNG",
    "electricity",
    "renewable energy",
    "renewable energy",
    "nuclear energy",
    "OPEC",
    "Saudi Arabia",
    "Russia energy",
    "pipeline",
]


modes = [
    "artlist", 
    "timelinevol", 
    "timelinevolinfo", 
    "timelinetone",
    "timelinesourcecountry",
    "tonechart"]
