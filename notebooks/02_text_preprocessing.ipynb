# %%
import asyncio
import pandas as pd

from pathlib import Path
import sys
project_root = Path.cwd().parent
sys.path.append(str(project_root))

from src.preprocessing import translate_text

# %%
df = pd.read_csv("../data/raw_data/gdelt_articles.csv")

# %%
df["Translated text"] = await asyncio.gather(
    *(translate_text(text) for text in df["Text"])
)
# Out:
# ---------------------------------------------------------------------------
# InvalidURL                                Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 df["Translated text"] = await asyncio.gather(
#       2     *(translate_text(text) for text in df["Text"])
#       3 )
#
# File ~/Desktop/CME Group/fin_insight_ds_proj_cme/cme_ds_km_kbb/src/preprocessing.py:16, in translate_text(text)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File /opt/anaconda3/envs/cme-ds-project-001/lib/python3.12/site-packages/googletrans/client.py:286, in Translator.translate(self, text, dest, src, **kwargs)
#     283     return result
#     285 origin = text
# --> 286 data, response = await self._translate(text, dest, src, kwargs)
#     288 # this code will be updated when the format is changed.
#     289 translated = "".join([d[0] if d[0] else "" for d in data[0]])
#
# File /opt/anaconda3/envs/cme-ds-project-001/lib/python3.12/site-packages/googletrans/client.py:128, in Translator._translate(self, text, dest, src, override)
#     118 params = utils.build_params(
#     119     client=self.client_type,
#     120     query=text,
#    (...)    124     override=override,
#     125 )
#     127 url = urls.TRANSLATE.format(host=self._pick_service_url())
# --> 128 r = await self.client.get(url, params=params)
#     130 if r.status_code == 200:
#     131     data = utils.format_json(r.text)
#
# File /opt/anaconda3/envs/cme-ds-project-001/lib/python3.12/site-packages/httpx/_client.py:1768, in AsyncClient.get(self, url, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1751 async def get(
#    1752     self,
#    1753     url: URL | str,
#    (...)   1761     extensions: RequestExtensions | None = None,
#    1762 ) -> Response:
#    1763     """
#    1764     Send a `GET` request.
#    1765
#    1766     **Parameters**: See `httpx.request`.
#    1767     """
# -> 1768     return await self.request(
#    1769         "GET",
#    1770         url,
#    1771         params=params,
#    1772         headers=headers,
#    1773         cookies=cookies,
#    1774         auth=auth,
#    1775         follow_redirects=follow_redirects,
#    1776         timeout=timeout,
#    1777         extensions=extensions,
#    1778     )
#
# File /opt/anaconda3/envs/cme-ds-project-001/lib/python3.12/site-packages/httpx/_client.py:1527, in AsyncClient.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1520     message = (
#    1521         "Setting per-request cookies=<...> is being deprecated, because "
#    1522         "the expected behaviour on cookie persistence is ambiguous. Set "
#    1523         "cookies directly on the client instance instead."
#    1524     )
#    1525     warnings.warn(message, DeprecationWarning, stacklevel=2)
# -> 1527 request = self.build_request(
#    1528     method=method,
#    1529     url=url,
#    1530     content=content,
#    1531     data=data,
#    1532     files=files,
#    1533     json=json,
#    1534     params=params,
#    1535     headers=headers,
#    1536     cookies=cookies,
#    1537     timeout=timeout,
#    1538     extensions=extensions,
#    1539 )
#    1540 return await self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File /opt/anaconda3/envs/cme-ds-project-001/lib/python3.12/site-packages/httpx/_client.py:378, in BaseClient.build_request(self, method, url, content, data, files, json, params, headers, cookies, timeout, extensions)
#     372     timeout = (
#     373         self.timeout
#     374         if isinstance(timeout, UseClientDefault)
#     375         else Timeout(timeout)
#     376     )
#     377     extensions = dict(**extensions, timeout=timeout.as_dict())
# --> 378 return Request(
#     379     method,
#     380     url,
#     381     content=content,
#     382     data=data,
#     383     files=files,
#     384     json=json,
#     385     params=params,
#     386     headers=headers,
#     387     cookies=cookies,
#     388     extensions=extensions,
#     389 )
#
# File /opt/anaconda3/envs/cme-ds-project-001/lib/python3.12/site-packages/httpx/_models.py:399, in Request.__init__(self, method, url, params, headers, cookies, content, data, files, json, stream, extensions)
#     383 def __init__(
#     384     self,
#     385     method: str,
#    (...)    396     extensions: RequestExtensions | None = None,
#     397 ) -> None:
#     398     self.method = method.upper()
# --> 399     self.url = URL(url) if params is None else URL(url, params=params)
#     400     self.headers = Headers(headers)
#     401     self.extensions = {} if extensions is None else dict(extensions)
#
# File /opt/anaconda3/envs/cme-ds-project-001/lib/python3.12/site-packages/httpx/_urls.py:119, in URL.__init__(self, url, **kwargs)
#     117     self._uri_reference = urlparse(url, **kwargs)
#     118 elif isinstance(url, URL):
# --> 119     self._uri_reference = url._uri_reference.copy_with(**kwargs)
#     120 else:
#     121     raise TypeError(
#     122         "Invalid type for url.  Expected str or httpx.URL,"
#     123         f" got {type(url)}: {url!r}"
#     124     )
#
# File /opt/anaconda3/envs/cme-ds-project-001/lib/python3.12/site-packages/httpx/_urlparse.py:198, in ParseResult.copy_with(self, **kwargs)
#     190 defaults = {
#     191     "scheme": self.scheme,
#     192     "authority": self.authority,
#    (...)    195     "fragment": self.fragment,
#     196 }
#     197 defaults.update(kwargs)
# --> 198 return urlparse("", **defaults)
#
# File /opt/anaconda3/envs/cme-ds-project-001/lib/python3.12/site-packages/httpx/_urlparse.py:269, in urlparse(url, **kwargs)
#     267 if value is not None:
#     268     if len(value) > MAX_URL_LENGTH:
# --> 269         raise InvalidURL(f"URL component '{key}' too long")
#     271     # If a component includes any ASCII control characters including \t, \r, \n,
#     272     # then treat it as invalid.
#     273     if any(char.isascii() and not char.isprintable() for char in value):
#
# InvalidURL: URL component 'query' too long
