# %%
import requests
import numpy as np

from pathlib import Path
import sys
project_root = Path.cwd().parent
sys.path.append(str(project_root))

from src.gdelt import fetch_data

# %%
print(fetch_data("Donald Trump", "artlist", "2m"))
# Out:
# {'articles': [{'url': 'https://www.independent.co.uk/news/world/americas/us-politics/eric-trump-donald-trump-jr-fathers-day-b3000446.html', 'url_mobile': '', 'title': 'Trump Organization gushes about Eric on Father Day – but forgets about Don Jr', 'seendate': '20260622T154500Z', 'socialimage': 'https://static.independent.co.uk/2026/05/18/14/2270188550..?trim=0,0,0,0&crop=1200:800', 'domain': 'independent.co.uk', 'language': 'English', 'sourcecountry': 'United Kingdom'}, {'url': 'https://www.yahoo.com/news/politics/articles/trumps-approval-hits-low-latest-191854396.html', 'url_mobile': '', 'title': 'Trump approval hits new low in latest poll', 'seendate': '20260728T201500Z', 'socialimage': 'https://s.yimg.com/lo/mysterio/api/1225e43d124c56497c4af74a17242b25026ea515f5c5c0690a3236fe5d4df7e6/lightyear_networkapi/resizefill_w1024_h683;quality_80;format_webp/https:%2F%2Fmedia.zenfs.com%2Fen%2Fusa_today_news_641%2Fc500f4e23fdab8d7ce7aa526074f60f4', 'domain': 'yahoo.com', 'language': 'Englis
# ...
