# %%
import requests
import numpy as np

from pathlib import Path
import sys
project_root = Path.cwd().parent
sys.path.append(str(project_root))

from src.gdelt import fetch_data
from src.scraping import scrape_articles

# %%
data = fetch_data("Oil", "artlist", "1h")
article_list = data["articles"]
article_urls = [article["url"] for article in article_list]
article_titles = [article["title"] for article in article_list]
# Out:
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.gdeltproject.org/api/v2/doc/doc?query=Oil&mode=artlist&timespan=1h&format=json

# %%
article_texts = scrape_articles(article_urls)
print(article_texts)
# Out:
# [{'https://argumenti.ru/politics/staraya-shema-vashington-snova-ukral-chuzhie-neftyanye-dengi-1005970': 'Президент Дональд Трамп всегда любил идею захвата чужих нефтяных запасов силой. Он утверждает, что добился этого в Венесуэле. «Война длилась 48\xa0минут, и мы заплатили за неё тем, что захватили. Это старый добрый способ. Победителю достаются трофеи»,\xa0– заявил он на прошлой неделе, выступая в Лас-Вегасе. При этом Трамп перевёл доходы Венесуэлы на секретный банковский счёт, находящийся под контролем правительства США. Однако он прав в том, что не придумал ничего нового\xa0– это старая американская схема.\nЛюбопытно, что другие официальные лица подают контроль США над венесуэльской нефтью совсем иначе. «Мы банкиры, мы не управляем средствами»,\xa0– заявил несколько месяцев назад министр финансов Скотт Бессент. «Это нефть народа Венесуэлы»,\xa0– вторил ему госсекретарь Марко Рубио несколькими неделями позже, утверждая, что правительство США лишь обеспечивает «удовлетворение потребностей венесуэльского народа» за счёт продажи нефти.\nВ каком-то смысле они оба правы. И оба врут. Вскоре после военной операции США в Венесуэле две страны заключили соглашение о передаче доходов от санкционированной венесуэльской нефти под контроль Минфина США. Формально эти деньги по-прежнему принадлежат Каракасу. На практике ими распоряжаются американские чиновники.\nТакая нефтяная сделка демонстрирует грубую, неподотчётную и глобальную власть, которую экономические санкции дают Вашингтону. Ни американский, ни венесуэльский народы не имеют чёткого представления о происходящем. Случай с Венесуэлой также показывает, что администрация Трампа очень озабочена установлением прямого экономического контроля, а не развитием свободных рынков, как регулярно утверждает американская пропаганда. Эту схему надо помнить всем, кто мечтает о возобновлении экономического сотрудничества с Белым домом.\nПо сути, власти США готовили почву для поглощения Венесуэлы очень давно. В течение последних двух десятилетий они вводили санкции против нефтяного и банковского секторов этой страны, препятствуя экспорту нефти и проведению операций в долларах. В\xa0итоге после военного вторжения и похищения Николаса Мадуро, о котором сейчас фактически забыли все мировые СМИ, новое венесуэльское руководство заключило со Штатами сделку. Трамп предоставил исключения из санкций и даже якобы защитил венесуэльские деньги от судебных исков со стороны своей страны. В обмен Каракас начал размещать свои нефтяные доходы на банковских счетах под «хранением» Минфина США.\nСначала деньги поступили на таинственный счёт в Катаре. В конце января Рубио заявил Конгрессу, что существует «краткосрочный механизм», позволяющий правительству Венесуэлы «ежемесячно представлять бюджет с указанием необходимых средств». Но уже неделю спустя Бессент заикался и отказывался отвечать на вопросы, какими юридическими полномочиями обладает Министерство финансов и какие письменные соглашения существуют. В итоге этот счёт пришлось закрыть, после того как через него прошло 500\xa0млн долларов.\nНовый счёт теоретически предусматривает больше сдержек и противовесов. Госдепартамент и правительство Венесуэлы весной даже объявили о привлечении сторонних аудиторов. Мол, это будет постоянная проверка. Но где сейчас находятся деньги\xa0– по-прежнему большая загадка. Об этом знают только Трамп и, видимо, некоторые приближённые к нему люди. Между тем британская газета The Financial Times подсчитала, что Венесуэла продала нефти на сумму более 13 млрд долларов в рамках нового соглашения. Отвечая на вопрос об этом отчёте, Дональд похвастался, что сумма «даже больше».\nНесмотря на обещание публиковать ежеквартальные аудиторские отчёты, Трамп ничего не сделал. Это серьёзно беспокоит демократов. На прошлой неделе они направили ещё одно письмо с требованием предоставить полную информацию. Даже республиканцы, поддерживавшие нынешнего президента, начали испытывать беспокойство из-за отсутствия прозрачности.\nВпрочем, надо понимать, что хот ...
