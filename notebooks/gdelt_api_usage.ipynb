# %%
import requests
import numpy as np

from pathlib import Path
import sys
project_root = Path.cwd().parent
sys.path.append(str(project_root))

from src.gdelt import fetch_data
from src.scraping import find_scrapeable_articles

# %%
data = fetch_data("Donald Trump", "artlist", "3m")
article_list = data["articles"]
print(article_list)
# Out:
# [{'url': 'https://www.yahoo.com/news/politics/articles/bill-cassidy-says-todd-blanche-171525517.html', 'url_mobile': '', 'title': 'Bill Cassidy says Todd Blanche vote wasnt  black or white decision  ', 'seendate': '20260809T180000Z', 'socialimage': 'https://s.yimg.com/lo/mysterio/api/7bcd12879793804cc02c2594e2ca92d8e768bb62a32587ed374073d495c18c43/lightyear_networkapi/resizefill_w1200%3Bquality_80%3Bformat_jpg/https%3A%2F%2Fmedia.zenfs.com%2Fen%2Fusa_today_news_641%2Ff1efcad25337697d7c2e91ac29bdbf31', 'domain': 'yahoo.com', 'language': 'English', 'sourcecountry': 'United States'}, {'url': 'https://www.newsbeast.gr/lifestyle/arthro/13284290/afairethikan-tragoudia-tis-teilor-souift-apo-vinteo-tis-proeklogikis-ekstrateias-tou-ntonalnt-trab', 'url_mobile': '', 'title': 'Αφαιρέθηκαν τραγούδια της Τέιλορ Σουίφτ από βίντεο της προεκλογικής εκστρατείας του Ντόναλντ Τραμπ', 'seendate': '20260809T223000Z', 'socialimage': 'https://www.newsbeast.gr/image/s1200x762/fill/file/files/1/2026/08/tramp
# ...

# %%
scrapeable_articles = find_scrapeable_articles(article_list)
print(scrapeable_articles)
