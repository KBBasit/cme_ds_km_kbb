# %%
import requests
import numpy as np

from pathlib import Path
import sys
project_root = Path.cwd().parent
sys.path.append(str(project_root))

from src.gdelt import fetch_data

# %%
data = fetch_data("Donald Trump", "artlist", "60min")
for i in data["articles"]:
    print(i["url"])
# Out:
# Attempt 1
# Status code: 429
# Please limit requests to one every 5 seconds or contact kalev.leetaru5@gmail.com for larger queries. All high-traffic users should switch to our ngrams dataset: https://blog.gdeltproject.org/using-the-new-web-ngrams-dataset-to-find-relevant-coverage/. For trend analysis, please see our daily newsletter briefings: https://blog.gdeltproject.org/announcing-our-new-daily-todays-trends-on-capitol-hill-todays-media-trends-newsletter-briefings/.
#
#
# https://www.yahoo.com/news/politics/articles/trumps-approval-hits-low-latest-191854396.html
# https://www.yahoo.com/news/politics/articles/brewery-promised-free-beer-trump-004322495.html
# https://www.yahoo.com/news/politics/articles/trump-unleashes-mi-democratic-senate-200647105.html
# https://www.yahoo.com/news/politics/articles/trump-urges-lawmakers-daylight-saving-172253424.html
# https://www.thedailybeast.com/trump-80-debuts-suspicious-new-hair-at-speech-in-las-vegas/
# ...
