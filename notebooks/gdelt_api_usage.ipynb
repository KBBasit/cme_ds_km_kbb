# %%
import requests
import numpy as np

from pathlib import Path
import sys
project_root = Path.cwd().parent
sys.path.append(str(project_root))

from src.gdelt import fetch_data
from src.scraping import find_scrapeable_articles

# %%
data = fetch_data("Donald Trump", "artlist", "2min")

article_list = data["articles"]

scrapeable_articles = find_scrapeable_articles(article_list)

print(scrapeable_articles)
# Out:
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.gdeltproject.org/api/v2/doc/doc?query=Donald+Trump&mode=artlist&timespan=2min&format=json
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.gdeltproject.org/api/v2/doc/doc?query=Donald+Trump&mode=artlist&timespan=2min&format=json
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.gdeltproject.org/api/v2/doc/doc?query=Donald+Trump&mode=artlist&timespan=2min&format=json
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data = fetch_data("Donald Trump", "artlist", "2min")
#       3 article_list = data["articles"]
#       5 scrapeable_articles = find_scrapeable_articles(article_list)
#
# File ~/Desktop/CME Group/fin_insight_ds_proj_cme/cme_ds_km_kbb/src/gdelt.py:34, in fetch_data(query, mode, timespan)
#      31     except requests.exceptions.RequestException as e:
#      32         print(f"Attempt {attempt + 1} failed: {e}")
# ---> 34 raise Exception("Failed to fetch data from GDELT API after 3 attempts")
#
# Exception: Failed to fetch data from GDELT API after 3 attempts
