# %%
import requests
import numpy as np

from pathlib import Path
import sys
project_root = Path.cwd().parent
sys.path.append(str(project_root))

from src.gdelt import fetch_data

# %%
data = fetch_data("Donald Trump", "artlist", "1m")
for i in data["articles"]:
    print(i["url"])
# Out:
# Rate limit exceeded. Retrying in 5 seconds... (Attempt 1/3)
# Rate limit exceeded. Retrying in 5 seconds... (Attempt 2/3)
# Rate limit exceeded. Retrying in 5 seconds... (Attempt 3/3)
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 data = fetch_data("Donald Trump", "artlist", "1m")
#       2 for i in data["articles"]:
#       3     print(i["url"])
#
# File ~/Desktop/CME Group/fin_insight_ds_proj_cme/cme_ds_km_kbb/src/gdelt.py:36, in fetch_data(query, mode, timespan)
#      33     response.raise_for_status()
#      34     return response.json()
# ---> 36 raise Exception("Failed to fetch data from GDELT API after 3 attempts")
#
# Exception: Failed to fetch data from GDELT API after 3 attempts
