# %%
import requests
import pandas as pd

from pathlib import Path
import sys
project_root = Path.cwd().parent
sys.path.append(str(project_root))

from src.gdelt import fetch_data
from src.gdelt import enrich_scraped_articles
from src.scraping import scrape_articles

# %%
response = fetch_data("oil", "artlist", "3m", max_records=25)
article_list = response["articles"]
article_urls = [article["url"] for article in article_list]
# Out:
# Attempt 1 failed: 429 Client Error: Too Many Requests for url: https://api.gdeltproject.org/api/v2/doc/doc?query=oil&mode=artlist&timespan=3m&maxrecords=25&format=json
# 429
# Attempt 2 failed: 429 Client Error: Too Many Requests for url: https://api.gdeltproject.org/api/v2/doc/doc?query=oil&mode=artlist&timespan=3m&maxrecords=25&format=json
# 429
# Attempt 3 failed: 429 Client Error: Too Many Requests for url: https://api.gdeltproject.org/api/v2/doc/doc?query=oil&mode=artlist&timespan=3m&maxrecords=25&format=json
# 429
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 response = fetch_data("oil", "artlist", "3m", max_records=25)
#       2 article_list = response["articles"]
#       3 article_urls = [article["url"] for article in article_list]
#
# File ~\Desktop\CME News Project\cme_ds_km_kbb\src\gdelt.py:55, in fetch_data(query, mode, timespan, timeout, max_records)
#      52     if attempt < 2:
#      53         time.sleep(5)
# ---> 55 raise Exception("Failed to fetch data from GDELT API after 3 attempts")
#
# Exception: Failed to fetch data from GDELT API after 3 attempts

# %%
scraped_articles = scrape_articles(article_urls)
scraped_articles = enrich_scraped_articles(scraped_articles, article_list)

# %%
df = pd.DataFrame({
    "Title": [article["title"] for article in scraped_articles],
    "URL": [article["url"] for article in scraped_articles],
    "GDELT seen date": [article["gdelt_seendate"] for article in scraped_articles],
    "Language": [article["language"] for article in scraped_articles],
    "Source country": [article["source_country"] for article in scraped_articles],
    "Text": [article["text"] for article in scraped_articles]
})

# %%
df.to_csv("../data/raw_data/gdelt_articles.csv", index=False)
